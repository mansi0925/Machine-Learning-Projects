# %% [markdown]
# # python operaters

# %% [markdown]
# - operaters are special symbols in python that are used to perform operations on variables

# %% [markdown]
# # arithmetic operaters

# %%
a=8
b=4

# %%
# addition
a+b
# Out:
# 12

# %%
# substraction

# %%
a-b
# Out:
# 4

# %%
#multiplication

# %%
a*b
# Out:
# 32

# %%
#division
a/b
# Out:
# 2.0

# %%
# modulo 
a%b
# Out:
# 0

# %%
b%a
# Out:
# 4

# %%
# floor division
b//a
# Out:
# 0

# %%
# power of operater
a**b
# Out:
# 4096

# %%
8**(3/4)
# Out:
# 4.756828460010884

# %% [markdown]
# # comparision operaters

# %%
x=12
y=10

# %%
5>8
# Out:
# False

# %%
x>y
# Out:
# True

# %%
y>x
# Out:
# False

# %%
2<3
# Out:
# True

# %%
x<y
# Out:
# False

# %%
3>=9
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
4<=1
# Out:
# False

# %%
y<=x
# Out:
# True

# %%
3==3.0000000000000000000000000000000000000
# Out:
# True

# %%
a='DATA'
b='SCIENCE'

# %%
a==b
# Out:
# False

# %%
'3'=='3.0'
# Out:
# False

# %%
2!=4
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
2!=2
# Out:
# False

# %% [markdown]
# # logical operaters

# %%
x=True 
y=False
z=True
a=False

# %%
x and z
# Out:
# True

# %%
x and y
# Out:
# False

# %%
y and a
# Out:
# False

# %%
x or y
# Out:
# True

# %%
x or z
# Out:
# True

# %%
y or a
# Out:
# False

# %%
not x
# Out:
# False

# %%
not y
# Out:
# True

# %%
b=5
c=7
d=12
e=8

# %%
(b<d) and (e<c)
# Out:
# False

# %% [markdown]
# # bitwise operaters

# %%
17&13
# Out:
# 1

# %%
25&16
# Out:
# 16

# %%
18|6
# Out:
# 22

# %% [markdown]
# # if conditional statement

# %%
a=11
if a>=10:
    print('i am inside if block')
# Out:
# i am inside if block

# %%
b=9
if b<10:
    print('i am in if block')
else:
    print('i am in else block')
# Out:
# i am in if block

# %%
age=16
if age>=18:
    print('eligible to vote')
else:
    print('not eligible to vote')
# Out:
# not eligible to vote

# %%
c=15
if c>21:
    print('i am in if block')
elif c<20:
    print('i am in first elif block')
elif c==20:
    print('i am in second elif block')
else:
    print('i am in else block')
# Out:
# i am in first elif block

# %%
num=0
if num>0:
    print('p')
elif num<0:
    print('n')
else:
    print('0')
# Out:
# 0

# %%
b='ab'
if b>0:
    print('p')
elif b<0:
    print('n')
elif b==0:
    print('0')
else:
    print('nothing')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12640\2566771101.py in <module>
#       1 b='ab'
# ----> 2 if b>0:
#       3     print('p')
#       4 elif b<0:
#       5     print('n')
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # input function

# %%
c=input('this is just a message to give input')
# Out:
# this is just a message to give input13

# %%
c
# Out:
# '15'

# %%
type(c)
# Out:
# str

# %%
a=44
if a>50:
    print('go to office')
elif a<40:
    print('stay home')
elif a==46:
    print('coffee shop')
elif a!=45:
    print('take leave')
# Out:
# take leave

# %%
m=int(input('enter the money you have : '))
if m>500:
    print('go shopping')
else:
    c=bool(int(input('did dad give money more than 500 1 for yes 0 for no')))
    if c:
        print('go shopping')
    else:
        d=bool(int(input('did mom give money 1 for yes 0 for no')))
        if d:
            print('go shopping')
        else:
            print('watch tv')
# Out:
# enter the money you have : 600
# go shopping

# %%
if False:
    print('if statement')
else:
    print('else statement')
# Out:
# else statement

# %%
 bool(0)
# Out:
# False

# %% [markdown]
# # nested if else

# %%
x=2
if x>=3:
    print('i am in first if')
    if x>4:
        print('i am in second if')
        if x==5:
            print(' i am in third if')

# %%
i=28
if i>0:
    print('i am in first if')
    if i<50:
        print('i am in second if')
        if i<26:
            print('I am in third if')
    else:
        print(' i am in third else')

else:
    print(' i am in else for firsr if')
# Out:
# i am in first if
# i am in second if

# %%
a=25
if a>0:
    print('i am in first')
    if i<50:
        print('i am second if')
        if i<26:
            print('j')
        else:
            ('t')
    else:
        print('c')
else:
    print('y')
# Out:
# i am in first
# i am second if

# %%
i=12
if i>10:
    print('i>10')
    if i>15:
        print('i>15')
    elif i<14:
        print('i<14')
# Out:
# i>10
# i<14

# %%
a=int(input('enter money you have'))
if a>=500:
    print('go out')
else:
    b= int(input('how much mom gave'))
    if a+b>=500:
        print('go out')
    else:
        c=int(input('how much dad gave'))
        if a+b+c>=500:
            print('go out')
        else:
            print('watch tv')
# Out:
# enter money you have600
# go out

# %% [markdown]
# # functions

# %%
print('hello')
# Out:
# hello

# %%
type(a)
# Out:
# int

# %%
def Eord(a):
    if a%2==0:
        print('even')
    else:
        print('odd')

# %%
Eord(17)
# Out:
# odd

# %%
# function that takes no arguments and returns no value
def hello():
    print('Hello python')

# %%
hello()
# Out:
# Hello python

# %%
# function that takes parameters but returns no value
def add(a,b,c,d):
    print(a+b+c+d)

# %%
b=add(3,4,5,6)
# Out:
# 18

# %%
b

# %%
add(34,45,56,67)
# Out:
# 202

# %%
# function that takes parameters and returns value
def mul(a,b,c):
    return(a*b*c)

# %%
mul(3,4,5)
# Out:
# 60

# %%
# functions that doesnt arguments and returns no value
def age():
    a=int(input('enter age : '))
    if a>=18:
        print('eligible to vote')
    else:
        print('not eligible to vote')

# %%
age()
# Out:
# enter age : 14
# not eligible to vote

# %%
def age2():
    a=int(input('enter age : '))
    if a>18:
        print('eligible to vote')
    else:
        print('not eligible  to vote')

# %%
age2()
# Out:
# enter age : 14
# not eligible  to vote

# %%
def area_rect(l,b):
    return(l*b)

# %%
area_rect(34,5)
# Out:
# 170

# %%
def area_rect1():
    l1=int(input('length is : ?'))
    b1=int(input('breadth is : ?'))
    return(l1*b1)

# %%
area_rect1()
# Out:
# length is : ?12
# breadth is : ?13
# 156

# %%
def age4(a):
    if a>=18:
        return('you are eligible to vote')
    else:
        return('not eligible to vote')

# %%
age4(18)
# Out:
# 'you are eligible to vote'

# %%
age4(14)
# Out:
# 'not eligible to vote'

# %%
def area_sqre(side):
    return(side*side)

# %%
area_sqre(5)
# Out:
# 25

# %%
area_sqre(34)
# Out:
# 1156

# %% [markdown]
# # anonymous functions

# %% [markdown]
# ## lambda function

# %%
add=lambda a,b,c: a+b+c

# %%
add(2,3,4)
# Out:
# 9

# %%
product=lambda a,b,c,d:a*b*c*d

# %%
product(2,3,4,5)
# Out:
# 120

# %% [markdown]
# # packages

# %% [markdown]
# # date time

# %% [markdown]
# ## date

# %%
from datetime import date

# %%
my_date=date(2023,2,7)

# %%
type(my_date)
# Out:
# datetime.date

# %%
my_date.day
# Out:
# 7

# %%
my_date.month
# Out:
# 2

# %%
my_date.year
# Out:
# 2023

# %%
my_date
# Out:
# datetime.date(2023, 2, 7)

# %%
def age(a):
    if a >= 18:
        print('eligoble to vote')
    else:
        print('not eligible to vote')

# %%
age(18)
# Out:
# eligoble to vote

# %%
age(14)
# Out:
# not eligible to vote
