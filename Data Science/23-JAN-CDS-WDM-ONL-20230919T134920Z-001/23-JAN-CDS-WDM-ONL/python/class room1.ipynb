# %% [markdown]
# # statements

# %% [markdown]
# - these are the instructions that python kernal can execute

# %%
# single line statements
c=10+20+30+40

# %%
c
# Out:
# 100

# %%
# multiple line statements
p1 = 20 + 30 \
+ 40 + 50 \
+ 60 + 70
print(p1)
# Out:
# 270

# %%
p1
# Out:
# 270

# %%
p3 = 20 +30 +40+\
30 +40\
+40

# %%
p3
# Out:
# 200

# %%
p4=2+3+4

# %%
p4
# Out:
# 9

# %% [markdown]
# # indentation

# %%
if 5>8:
    print('hello world')
    print('something else')

# %%
def Function():
    print("hello python")

# %%
p=7
if p>8:
    print('Hello world')

# %% [markdown]
# # docstring

# %%
print(square.__doc__)
# Out:
#  square :- this function gives you square of the number

# %%
print(type.__doc__)
# Out:
# type(object) -> the object's type
# type(name, bases, dict, **kwds) -> a new type

# %%
def square(num):
    ''' square :- this function gives you square of the number '''
    return num*num

# %%
def square(num):
    a=10
    b=20
    a+b
    return num*num

# %% [markdown]
# # variables

# %% [markdown]
# - variables are the memory locations where we store the data

# %%
k=30 # variable creation

# %%
k # calling the variable
# Out:
# 30

# %%
print(k) # printing the variable
# Out:
# 30

# %% [markdown]
# # variable assignment

# %%
intvar=10
floatvar=2.57
strvar="hello python"

# %%
intvar1,floatvar1,strvar1=11,3.57,"Hello Python" #multiple assignment

# %%
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# hello python

# %% [markdown]
# # data types

# %% [markdown]
# ## Numeric

# %%
val1=10

# %%
type(val1)
# Out:
# int

# %%
val2=2.45

# %%
type(val2)
# Out:
# float

# %%
val3=4+10j

# %%
type(val3)
# Out:
# complex

# %% [markdown]
# # Boolean

# %% [markdown]
# - booleyan has only two values True or False

# %%
bool1=True

# %%
bool1
# Out:
# True

# %%
type(bool1)
# Out:
# bool

# %%
bool2=False

# %%
bool2
# Out:
# False

# %%
type(bool2)
# Out:
# bool

# %%
bool(2)
# Out:
# True

# %%
bool(67)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('RAm')
# Out:
# True

# %% [markdown]
# # Strings

# %% [markdown]
# ## string creation

# %%
str1="hello python"

# %%
mystr= "Hello World"

# %% [markdown]
# ## String Indexing

# %%
str1[6]
# Out:
# 'p'

# %%
str1[-1]
# Out:
# 'n'

# %%
str1[-6]
# Out:
# 'p'

# %%
str1[-11]
# Out:
# 'e'

# %% [markdown]
# # string slicing

# %%
str1
# Out:
# 'hello python'

# %%
str1[6:9]
# Out:
# 'pyt'

# %%
str1[-6:-3]
# Out:
# 'pyt'

# %%
str2= "Data is the new fuel"

# %%
str2[12:15]
# Out:
# 'new'

# %%
str2[-8:-5]
# Out:
# 'new'

# %%
str2[::2]
# Out:
# 'Dt stenwfe'

# %%
str2[:8:2]
# Out:
# 'Dt s'

# %%
str2[9::3]
# Out:
# 'hn e'

# %%
str2[::-1]
# Out:
# 'leuf wen eht si ataD'

# %%
str2[-11::3]
# Out:
# 'hn e'

# %%
str2
# Out:
# 'Data is the new fuel'

# %%
str2[-12::3]
# Out:
# 't wu'

# %%
str2[::-1]
# Out:
# 'leuf wen eht si ataD'

# %%
str2[-8:-5]
# Out:
# 'new'

# %%
str2[-6:-9:-1]
# Out:
# 'wen'

# %%
str2[14:11:-1]
# Out:
# 'wen'

# %% [markdown]
# # updating and deleting the string

# %%
str1='hello python'

# %%
str1[0:2]='hi'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-ffbd8eb86445> in <cell line: 1>()
# ----> 1 str1[0:2]='hi'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# - strings are immutable i.e once created cannot be changed

# %%
str3=str1.replace('he','hi')

# %%
str1
# Out:
# 'hello python'

# %%
str3
# Out:
# 'hillo python'

# %%
del str3

# %%
str3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12776\788676521.py in <module>
# ----> 1 str3
#
# NameError: name 'str3' is not defined

# %%
del str1

# %%
str1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12776\934771681.py in <module>
# ----> 1 str1
#
# NameError: name 'str1' is not defined

# %% [markdown]
# # string concatination

# %%
s1='data'
s2='science'

# %%
s3=s1+s2

# %%
s4
# Out:
# 'data science'

# %%
s4=s1+' '+s2

# %%
s4=s1+" "+s2

# %%
s4
# Out:
# 'data science'

# %% [markdown]
# # membership operater

# %%
mystr1='Hello Everyone'

# %%
'Helo' in mystr1
# Out:
# False

# %%
'every' in mystr1
# Out:
# False

# %%
mystr1
# Out:
# 'Hello Everyone'

# %% [markdown]
# # string partitioning

# %%
mystr2='hello python'

# %%
mystr2.partition('lo')
# Out:
# ('hel', 'lo', ' python')

# %%
mystr3='data is the new fuel'

# %%
mystr3.partition(' ')
# Out:
# ('data', ' ', 'is the new fuel')

# %% [markdown]
# # string functions

# %%
mystr1
# Out:
# 'Hello Everyone'

# %%
mystr1.count('e')
# Out:
# 3

# %%
mystr2='      hello python     '

# %%
mystr2
# Out:
# '      hello python     '

# %%
mystr2.strip()
# Out:
# 'hello python'

# %%
mystr2
# Out:
# '      hello python     '

# %%
mystr2.lstrip()
# Out:
# 'hello python     '

# %%
mystr2.rstrip()
# Out:
# '      hello python'

# %%
mystr4 ='*****Hello ******* Python********'

# %%
mystr4.strip('*')
# Out:
# 'Hello ******* Python'

# %%
mystr4.lstrip('*')
# Out:
# 'Hello ******* Python********'

# %%
mystr4.rstrip('*')
# Out:
# '*****Hello ******* Python'

# %%
mystr3='HELLO PYTHON'

# %%
mystr3.lower()
# Out:
# 'hello python'

# %%
mystr4='hello python '

# %%
mystr4.upper()
# Out:
# 'HELLO PYTHON'

# %%
mystr4.startswith('hello')
# Out:
# True

# %%
mystr4.endswith('python')
# Out:
# False

# %%
mystr5="one,two,three,four,five,six"

# %%
mystr5.split('e')
# Out:
# ['on', ',two,thr', '', ',four,fiv', ',six']

# %% [markdown]
# # Type casting

# %% [markdown]
# - method of changing from one data type to the other data type

# %% [markdown]
# ## Auto typecasting

# %%
4+3.57+True
# Out:
# 8.57

# %%
4+3+'data'+True
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12776\3130085056.py in <module>
# ----> 1 4+3+'data'+True
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
5.67+True
# Out:
# 6.67

# %%
3+4j+6
# Out:
# (9+4j)

# %%
3+4+'123'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12776\1166983539.py in <module>
# ----> 1 3+4+'123'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # forced typecasting

# %%
a=9.7

# %%
type(a)
# Out:
# float

# %%
a=int(a)

# %%
a
# Out:
# 9

# %%
type(a)
# Out:
# int

# %%
int('data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12776\1447147357.py in <module>
# ----> 1 int('data')
#
# ValueError: invalid literal for int() with base 10: 'data'

# %%
b=int(float('123.8'))

# %%
b
# Out:
# 123

# %%
bool('anything other than zero is True')
# Out:
# True

# %%
bool('0')
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(8743)
# Out:
# True

# %%
str(89)
# Out:
# '89'

# %%
str(True)
# Out:
# 'True'
