# %%
import numpy as mp
import pandas as pd

# %%
df = pd.read_csv('ABC.csv')

# %%
df
# Out:
#     Unnamed: 0    Eastern Conference                   W                   L  \
# 0            0     Atlantic Division   Atlantic Division   Atlantic Division
# 1            1      Toronto Raptors*                  49                  33
# 2            2       Boston Celtics*                  40                  42
# 3            3        Brooklyn Nets*                  38                  44
# 4            4    Philadelphia 76ers                  18                  64
# 5            5       New York Knicks                  17                  65
# 6            6      Central Division    Central Division    Central Division
# 7            7  Cleveland Cavaliers*                  53                  29
# 8            8        Chicago Bulls*                  50                  32
# 9            9      Milwaukee Bucks*                  41                  41
# 10          10        Indiana Pacers                  38                  44
# ...

# %%
df2 = pd.read_excel('ex1.xlsx')

# %%
df2
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
pd.read_csv('ex1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv(r'C:\Users\Datamites\Desktop\23 JAN WDM\CDS-03-Pandas\ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('C:/Users/Datamites/Desktop/23 JAN WDM/CDS-03-Pandas/ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
df3 = pd.read_table('test.tsv')
df3
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
pd.read_csv('test.tsv', sep='\t')
# Out:
#             test     test   test.1   test.2   test.3
# Data        Data     Data     Data     Data     Data
# Science  Science  Science  Science  Science  Science

# %%
pd.read_csv('ex7.csv')
# Out:
#    a*b*c
# 0  1*2*3
# 1  1*2*3

# %%
pd.read_csv('ex7.csv', sep = '*')
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
pd.read_csv(r'C:\Users\Datamites\Desktop\23 JAN WDM\CDS-03-Pandas\train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df5 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015.html')
df5
# Out:
# [      Eastern Conference                   W                   L  \
#  0      Atlantic Division   Atlantic Division   Atlantic Division
#  1       Toronto Raptors*                  49                  33
#  2        Boston Celtics*                  40                  42
#  3         Brooklyn Nets*                  38                  44
#  4     Philadelphia 76ers                  18                  64
#  5        New York Knicks                  17                  65
#  6       Central Division    Central Division    Central Division
#  7   Cleveland Cavaliers*                  53                  29
#  8         Chicago Bulls*                  50                  32
#  9       Milwaukee Bucks*                  41                  41
#  10        Indiana Pacers                  38                  44
#  11       Detroit Pistons                  32                  50
#  12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
df5[6]
# Out:
#     Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1    Los Angeles Clippers*  82  19730  41.5  87.7  0.473  10.6  28.3
# 1    2   Golden State Warriors*  82  19730  42.2  88.3  0.478  10.9  27.4
# 2    3     Cleveland Cavaliers*  82  19780  40.6  88.6  0.458  10.9  29.6
# 3    4         Toronto Raptors*  82  19855  40.5  88.9  0.455   9.5  26.8
# 4    5        Dallas Mavericks*  82  19880  41.3  89.3  0.463   9.3  26.4
# 5    6           Atlanta Hawks*  82  19730  40.4  86.7  0.466  10.6  27.9
# 6    7       San Antonio Spurs*  82  19955  41.1  87.9  0.468   8.7  23.7
# 7    8    New Orleans Pelicans*  82  19780  41.3  90.2  0.457   7.8  21.0
# 8    9  Portland Trail Blazers*  82  19855  40.7  90.4  0.450  10.4  28.6
# 9   10    Oklahoma City Thunder  82  19830  40.3  90.0  0.447   8.0  23.6
# 10  11           Chicago Bulls*  82  19880  39.0  88.4  0.442   8.4  23.7
# 11  12         Houston Rockets*  82  19805  38.1  85.8  0.444  11.7  33.6
# ...

# %%
df5[2]
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0   Golden State Warriors*  82  240.6  41.6  87.0  0.478  10.8  27.0
# 1    2.0    Los Angeles Clippers*  82  240.6  39.4  83.3  0.473  10.1  26.9
# 2    3.0        Dallas Mavericks*  82  242.4  39.7  85.8  0.463   8.9  25.4
# 3    4.0    Oklahoma City Thunder  82  241.8  38.8  86.8  0.447   7.7  22.7
# 4    5.0         Toronto Raptors*  82  242.1  37.9  83.3  0.455   8.9  25.1
# 5    6.0         Houston Rockets*  82  241.5  37.0  83.3  0.444  11.4  32.7
# 6    7.0       San Antonio Spurs*  82  243.4  39.1  83.6  0.468   8.3  22.5
# 7    8.0     Cleveland Cavaliers*  82  241.2  37.7  82.2  0.458  10.1  27.5
# 8    9.0  Portland Trail Blazers*  82  242.1  38.7  86.0  0.450   9.8  27.2
# 9   10.0           Atlanta Hawks*  82  240.6  38.1  81.7  0.466  10.0  26.2
# 10  11.0             Phoenix Suns  82  242.4  38.8  85.8  0.452   8.5  25.0
# ...

# %%
pd.read_json('example.json')
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.read_csv('ABC.csv')
df
# Out:
#     Unnamed: 0    Eastern Conference                   W                   L  \
# 0            0     Atlantic Division   Atlantic Division   Atlantic Division
# 1            1      Toronto Raptors*                  49                  33
# 2            2       Boston Celtics*                  40                  42
# 3            3        Brooklyn Nets*                  38                  44
# 4            4    Philadelphia 76ers                  18                  64
# 5            5       New York Knicks                  17                  65
# 6            6      Central Division    Central Division    Central Division
# 7            7  Cleveland Cavaliers*                  53                  29
# 8            8        Chicago Bulls*                  50                  32
# 9            9      Milwaukee Bucks*                  41                  41
# 10          10        Indiana Pacers                  38                  44
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Eastern Conference                  W                  L  \
# 0           0   Atlantic Division  Atlantic Division  Atlantic Division
# 1           1    Toronto Raptors*                 49                 33
# 2           2     Boston Celtics*                 40                 42
# 3           3      Brooklyn Nets*                 38                 44
# 4           4  Philadelphia 76ers                 18                 64
#
#                 W/L%                 GB               PS/G               PA/G  \
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1               .598                  —              104.0              100.9
# 2               .488                9.0              101.4              101.2
# 3               .463               11.0               98.0              100.9
# 4               .220               31.0               92.0              101.0
#
#                  SRS
# 0  Atlantic Division
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0   Eastern Conference   W   L  W/L%    GB   PS/G   PA/G    SRS
# 13          13       Atlanta Hawks*  60  22  .732     —  102.5   97.1   4.75
# 14          14  Washington Wizards*  46  36  .561  14.0   98.5   97.8   0.17
# 15          15           Miami Heat  37  45  .451  23.0   94.7   97.3  -2.92
# 16          16    Charlotte Hornets  33  49  .402  27.0   94.2   97.3  -3.44
# 17          17        Orlando Magic  25  57  .305  35.0   95.7  101.4  -5.87

# %%
df.head(2)
# Out:
#    Unnamed: 0 Eastern Conference                  W                  L  \
# 0           0  Atlantic Division  Atlantic Division  Atlantic Division
# 1           1   Toronto Raptors*                 49                 33
#
#                 W/L%                 GB               PS/G               PA/G  \
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1               .598                  —              104.0              100.9
#
#                  SRS
# 0  Atlantic Division
# 1               2.45

# %%
df.head(9)
# Out:
#    Unnamed: 0    Eastern Conference                  W                  L  \
# 0           0     Atlantic Division  Atlantic Division  Atlantic Division
# 1           1      Toronto Raptors*                 49                 33
# 2           2       Boston Celtics*                 40                 42
# 3           3        Brooklyn Nets*                 38                 44
# 4           4    Philadelphia 76ers                 18                 64
# 5           5       New York Knicks                 17                 65
# 6           6      Central Division   Central Division   Central Division
# 7           7  Cleveland Cavaliers*                 53                 29
# 8           8        Chicago Bulls*                 50                 32
#
#                 W/L%                 GB               PS/G               PA/G  \
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# ...

# %%
df.tail(7)
# Out:
#     Unnamed: 0   Eastern Conference                   W                   L  \
# 11          11      Detroit Pistons                  32                  50
# 12          12   Southeast Division  Southeast Division  Southeast Division
# 13          13       Atlanta Hawks*                  60                  22
# 14          14  Washington Wizards*                  46                  36
# 15          15           Miami Heat                  37                  45
# 16          16    Charlotte Hornets                  33                  49
# 17          17        Orlando Magic                  25                  57
#
#                   W/L%                  GB                PS/G  \
# 11                .390                21.0                98.5
# 12  Southeast Division  Southeast Division  Southeast Division
# 13                .732                   —               102.5
# 14                .561                14.0                98.5
# ...

# %%
df.head(11)
# Out:
#     Unnamed: 0    Eastern Conference                  W                  L  \
# 0            0     Atlantic Division  Atlantic Division  Atlantic Division
# 1            1      Toronto Raptors*                 49                 33
# 2            2       Boston Celtics*                 40                 42
# 3            3        Brooklyn Nets*                 38                 44
# 4            4    Philadelphia 76ers                 18                 64
# 5            5       New York Knicks                 17                 65
# 6            6      Central Division   Central Division   Central Division
# 7            7  Cleveland Cavaliers*                 53                 29
# 8            8        Chicago Bulls*                 50                 32
# 9            9      Milwaukee Bucks*                 41                 41
# 10          10        Indiana Pacers                 38                 44
#
#                  W/L%                 GB               PS/G  \
# ...

# %%
df = pd.read_csv('ABC.csv')
df.head()
# Out:
#    Unnamed: 0  Eastern Conference                  W                  L  \
# 0           0   Atlantic Division  Atlantic Division  Atlantic Division
# 1           1    Toronto Raptors*                 49                 33
# 2           2     Boston Celtics*                 40                 42
# 3           3      Brooklyn Nets*                 38                 44
# 4           4  Philadelphia 76ers                 18                 64
#
#                 W/L%                 GB               PS/G               PA/G  \
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1               .598                  —              104.0              100.9
# 2               .488                9.0              101.4              101.2
# 3               .463               11.0               98.0              100.9
# 4               .220               31.0               92.0              101.0
#
#                  SRS
# 0  Atlantic Division
# ...

# %%
df = pd.read_csv('ABC.csv', header=None)
df.head()
# Out:
#      0                   1                  2                  3      4  \
# 0  NaN  Eastern Conference                  W                  L   W/L%
# 1  0.0   Atlantic Division  Atlantic Division  Atlantic Division    NaN
# 2  1.0    Toronto Raptors*                 49                NaN  0.598
# 3  2.0     Boston Celtics*                 40                 42  0.488
# 4  3.0      Brooklyn Nets*                 38                 44  0.463
#
#                    5                  6                  7                  8
# 0                 GB               PS/G               PA/G                SRS
# 1  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 2                  —                104              100.9               2.45
# 3                  9              101.4              101.2               -0.4
# 4                 11                 98              100.9              -3.13

# %%
df = pd.read_csv('ABC.csv', header=2)
df.head()
# Out:
#    1    Toronto Raptors*                49        Unnamed: 3  \
# 0  2     Boston Celtics*                40                42
# 1  3      Brooklyn Nets*                38                44
# 2  4  Philadelphia 76ers                18                64
# 3  5     New York Knicks                17                65
# 4  6    Central Division  Central Division  Central Division
#
#               0.598                 —               104             100.9  \
# 0             0.488                 9             101.4             101.2
# 1             0.463                11                98             100.9
# 2              0.22                31                92               101
# 3             0.207                32              91.9             101.2
# 4  Central Division  Central Division  Central Division  Central Division
#
#                2.45
# 0              -0.4
# 1             -3.13
# 2             -9.04
# 3              -9.5
# 4  Central Division

# %%
df = pd.read_csv('ABC.csv', header=3)
df.head()
# Out:
#    2       Boston Celtics*                40                42  \
# 0  3        Brooklyn Nets*                38                44
# 1  4    Philadelphia 76ers                18                64
# 2  5       New York Knicks                17                65
# 3  6      Central Division  Central Division  Central Division
# 4  7  Cleveland Cavaliers*                53                29
#
#               0.488                 9             101.4             101.2  \
# 0             0.463                11                98             100.9
# 1              0.22                31                92               101
# 2             0.207                32              91.9             101.2
# 3  Central Division  Central Division  Central Division  Central Division
# 4             0.646                 —             103.1              98.7
#
#                -0.4
# 0             -3.13
# 1             -9.04
# 2              -9.5
# 3  Central Division
# 4              4.08

# %%
df = pd.read_csv('ABC.csv')
df.head()
# Out:
#    Unnamed: 0  Eastern Conference                  W                  L  \
# 0           0   Atlantic Division  Atlantic Division  Atlantic Division
# 1           1    Toronto Raptors*                 49                NaN
# 2           2     Boston Celtics*                 40                 42
# 3           3      Brooklyn Nets*                 38                 44
# 4           4  Philadelphia 76ers                 18                 64
#
#     W/L%                 GB               PS/G               PA/G  \
# 0    NaN  Atlantic Division  Atlantic Division  Atlantic Division
# 1  0.598                  —                104              100.9
# 2  0.488                  9              101.4              101.2
# 3  0.463                 11                 98              100.9
# 4   0.22                 31                 92                101
#
#                  SRS
# 0  Atlantic Division
# 1               2.45
# 2               -0.4
# 3              -3.13
# 4              -9.04

# %%
pd.read_csv(r'C:\Users\Datamites\Desktop\23 JAN WDM\CDS-03-Pandas\Examples for file reading-02\ABC.csv')
# Out:
#     Unnamed: 0    Eastern Conference                   W                   L  \
# 0            0     Atlantic Division   Atlantic Division   Atlantic Division
# 1            1      Toronto Raptors*                  49                 NaN
# 2            2       Boston Celtics*                  40                  42
# 3            3        Brooklyn Nets*                  38                  44
# 4            4    Philadelphia 76ers                  18                  64
# 5            5       New York Knicks                  17                  65
# 6            6      Central Division    Central Division    Central Division
# 7            7  Cleveland Cavaliers*                  53                  29
# 8            8        Chicago Bulls*                  50                  32
# 9            9      Milwaukee Bucks*                  41                  41
# 10          10        Indiana Pacers                  38                  44
# ...

# %%
df = pd.read_csv('ABC.csv', index_col='Eastern Conference')
df.head()
# Out:
#                     Unnamed: 0                  W                  L   W/L%  \
# Eastern Conference
# Atlantic Division            0  Atlantic Division  Atlantic Division    NaN
# Toronto Raptors*             1                 49                NaN  0.598
# Boston Celtics*              2                 40                 42  0.488
# Brooklyn Nets*               3                 38                 44  0.463
# Philadelphia 76ers           4                 18                 64   0.22
#
#                                    GB               PS/G               PA/G  \
# Eastern Conference
# Atlantic Division   Atlantic Division  Atlantic Division  Atlantic Division
# Toronto Raptors*                    —                104              100.9
# Boston Celtics*                     9              101.4              101.2
# Brooklyn Nets*                     11                 98              100.9
# Philadelphia 76ers                 31                 92                101
#
# ...

# %%
df = pd.read_csv('ABC.csv', index_col=0)
df.head()
# Out:
#    Eastern Conference                  W                  L   W/L%  \
# 0   Atlantic Division  Atlantic Division  Atlantic Division    NaN
# 1    Toronto Raptors*                 49                NaN  0.598
# 2     Boston Celtics*                 40                 42  0.488
# 3      Brooklyn Nets*                 38                 44  0.463
# 4  Philadelphia 76ers                 18                 64   0.22
#
#                   GB               PS/G               PA/G                SRS
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1                  —                104              100.9               2.45
# 2                  9              101.4              101.2               -0.4
# 3                 11                 98              100.9              -3.13
# 4                 31                 92                101              -9.04

# %%
df7 = pd.read_csv('ABC.csv', header = 2, index_col=3)
df7.head()
# Out:
#                   1    Toronto Raptors*                49             0.598  \
# 42                2     Boston Celtics*                40             0.488
# 44                3      Brooklyn Nets*                38             0.463
# 64                4  Philadelphia 76ers                18              0.22
# 65                5     New York Knicks                17             0.207
# Central Division  6    Central Division  Central Division  Central Division
#
#                                  —               104             100.9  \
# 42                               9             101.4             101.2
# 44                              11                98             100.9
# 64                              31                92               101
# 65                              32              91.9             101.2
# Central Division  Central Division  Central Division  Central Division
#
#                               2.45
# 42                            -0.4
# ...

# %%
df7 = pd.read_csv('ABC.csv')
df7.head()
# Out:
#    Unnamed: 0  Eastern Conference                  W                  L  \
# 0           0   Atlantic Division  Atlantic Division  Atlantic Division
# 1           1    Toronto Raptors*                 49                NaN
# 2           2     Boston Celtics*                 40                 42
# 3           3      Brooklyn Nets*                 38                 44
# 4           4  Philadelphia 76ers                 18                 64
#
#     W/L%                 GB               PS/G               PA/G  \
# 0    NaN  Atlantic Division  Atlantic Division  Atlantic Division
# 1  0.598                  —                104              100.9
# 2  0.488                  9              101.4              101.2
# 3  0.463                 11                 98              100.9
# 4   0.22                 31                 92                101
#
#                  SRS
# 0  Atlantic Division
# 1               2.45
# 2               -0.4
# 3              -3.13
# 4              -9.04

# %%
df7 = pd.read_csv('ABC.csv', index_col=False)
df7.head()
# Out:
#    Unnamed: 0  Eastern Conference                  W                  L  \
# 0           0   Atlantic Division  Atlantic Division  Atlantic Division
# 1           1    Toronto Raptors*                 49                NaN
# 2           2     Boston Celtics*                 40                 42
# 3           3      Brooklyn Nets*                 38                 44
# 4           4  Philadelphia 76ers                 18                 64
#
#     W/L%                 GB               PS/G               PA/G  \
# 0    NaN  Atlantic Division  Atlantic Division  Atlantic Division
# 1  0.598                  —                104              100.9
# 2  0.488                  9              101.4              101.2
# 3  0.463                 11                 98              100.9
# 4   0.22                 31                 92                101
#
#                  SRS
# 0  Atlantic Division
# 1               2.45
# 2               -0.4
# 3              -3.13
# 4              -9.04

# %%
df7.to_csv('ABCDE.csv')

# %%
df7.to_excel('ABCD.xlsx')

# %%
df9 = pd.read_csv('ex5.csv')
df9
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df9.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
df9.isnull().sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
df10 = pd.read_csv('ABC.csv')
df10.head()
# Out:
#    Unnamed: 0 Eastern Conference                  W                  L   W/L%  \
# 0           0  Atlantic Division  Atlantic Division  Atlantic Division    NaN
# 1           1   Toronto Raptors*                 49                NaN  0.598
# 2           2    Boston Celtics*                 40                 42  0.488
# 3           3     Brooklyn Nets*                 38                 44  0.463
# 4           4                NaN                 18                 64    NaN
#
#                   GB               PS/G               PA/G                SRS
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1                  —                104              100.9               2.45
# 2                  9              101.4              101.2               -0.4
# 3                 11                 98              100.9              -3.13
# 4                 31                 92                101              -9.04

# %%
df10.isnull()
# Out:
#     Unnamed: 0  Eastern Conference      W      L   W/L%     GB   PS/G   PA/G  \
# 0        False               False  False  False   True  False  False  False
# 1        False               False  False   True  False  False  False  False
# 2        False               False  False  False  False  False  False  False
# 3        False               False  False  False  False  False  False  False
# 4        False                True  False  False   True  False  False  False
# 5        False               False  False  False  False  False  False  False
# 6        False               False  False  False  False  False  False  False
# 7        False               False   True  False  False  False  False  False
# 8        False               False  False  False  False  False  False  False
# 9        False               False  False  False  False  False  False  False
# 10       False               False  False  False   True  False   True  False
# ...

# %%
df10.isnull().sum()
# Out:
# Unnamed: 0            0
# Eastern Conference    2
# W                     1
# L                     1
# W/L%                  4
# GB                    0
# PS/G                  1
# PA/G                  0
# SRS                   1
# dtype: int64
