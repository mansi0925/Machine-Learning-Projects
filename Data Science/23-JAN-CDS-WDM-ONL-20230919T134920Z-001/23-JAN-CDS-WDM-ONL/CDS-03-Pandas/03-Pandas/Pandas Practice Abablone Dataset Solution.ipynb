# %% [markdown]
# # Introduction
#
# Abalone is a common name for any of a group of small to very large marine gastropod molluscs in the family Haliotidae. Abalones are marine snails.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/LivingAbalone.JPG/330px-LivingAbalone.JPG)
#
# The shells of abalones have a low, open spiral structure, and are characterized by several open respiratory pores in a row near the shell's outer edge. The thick inner layer of the shell is composed of nacre (mother-of-pearl), which in many species is highly iridescent, giving rise to a range of strong, changeable colors which make the shells attractive to humans as decorative objects, jewelry, and as a source of colorful mother-of-pearl.
#
# The flesh of abalones is widely considered to be a desirable food, and is consumed raw or cooked by a variety of cultures.
#
# More Information on [Abalone](https://en.wikipedia.org/wiki/Abalone)
#
# The dataset being used is available on [UCI datasets](https://archive.ics.uci.edu/ml/datasets/Abalone)

# %% [markdown]
# # Solve the questions in this notebook starting from #1 and then solve the rest sequentially.

# %% [markdown]
# # 1
# Read the dataset https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data using pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data')
df.head()
# Out:
#    M  0.455  0.365  0.095   0.514  0.2245   0.101   0.15  15
# 0  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 1  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 2  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 3  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7
# 4  I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.120   8

# %% [markdown]
# # 2
# Check the column names

# %%
df.columns
# Out:
# Index(['M', '0.455', '0.365', '0.095', '0.514', '0.2245', '0.101', '0.15',
#        '15'],
#       dtype='object')

# %% [markdown]
# # 3
# As apparent, the first row of the data becomes the column names. Import the dataset again while resolving this issue without loosing any data

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data', header=None)
df.head()
# Out:
#    0      1      2      3       4       5       6      7   8
# 0  M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.150  15
# 1  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 2  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 3  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 4  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7

# %% [markdown]
# # 4
# Replace the default column names with
# ["Sex", "Length", "Diameter", "Height", "Whole_weight", "Shucked_weight", "Viscera_weight", "Shell_weight", "Rings"]
#
# The description of the columns is given below
#
#
# |Name | Data Type | Measurement Unit | Description|
# |-----|-----------|----------|---|
# |Sex | nominal | -- | M, F, and I (infant)|
# |Length | continuous | mm | Longest shell measurement|
# |Diameter | continuous | mm | perpendicular to length|
# |Height | continuous | mm | with meat in shell|
# |Whole weight | continuous | grams | whole abalone|
# |Shucked weight | continuous | grams | weight of meat|
# |Viscera weight | continuous | grams | gut weight (after bleeding)|
# |Shell weight | continuous | grams | after being dried|
# |Rings | integer | -- | +1.5 gives the age in years

# %%
df.columns = ["Sex", "Length", "Diameter", "Height", "Whole_weight", "Shucked_weight", "Viscera_weight", "Shell_weight", "Rings"]
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 5
# Check the shape of the data

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# # 6
# Calculate the desciptive properties of the data

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# # 7
# Check the datatype of all of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # 8
# Check if these is any NaN value (missing) in the dataset

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # 9
# What is the mean height of Abablone accoring to the dataset?

# %%
df.Height.mean()
# Out:
# 0.1395163993296614

# %% [markdown]
# # 10
# Check the mode of Sex column

# %%
df.Sex.mode()
# Out:
# 0    M
# dtype: object

# %% [markdown]
# # 11
# What is the minimum and maximum Length of Abalones in this dataset **in centimeters**?

# %%
# function to convert milimeter values to centimeter
def mm_to_cm(val):
    return val/10

# %%
min_mm_val = df.Length.min()
min_cm_val = mm_to_cm(min_mm_val)
print ('Minimum length in cm', min_cm_val)
# Out:
# Minimum length in cm 0.0075

# %%
max_mm_val = df.Length.max()
max_cm_val = mm_to_cm(max_mm_val)
print ('Maximum length in cm', max_cm_val)
# Out:
# Maximum length in cm 0.08149999999999999

# %% [markdown]
# # 12
# The Sex column contains three unique values, check what they are

# %%
df.Sex.unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %% [markdown]
# # 13
# The unique values and their corresponding values are M for Male, F for Female, and I for Infant.
#
# Check the count of all three values

# %%
df.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# # 14
# Draw a pie chart of all of the values

# %%
df.Sex.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Sex'>

# %% [markdown]
# # 15
# Try soring the values accoring to the Height in ascending order

# %%
df.sort_values('Height')
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 3996   I   0.315     0.230   0.000        0.1340          0.0575
# 1257   I   0.430     0.340   0.000        0.4280          0.2065
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 2169   I   0.165     0.115   0.015        0.0145          0.0055
# 1174   F   0.635     0.495   0.015        1.1565          0.5115
# ...   ..     ...       ...     ...           ...             ...
# 1763   M   0.775     0.630   0.250        2.7795          1.3485
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
# 2179   F   0.595     0.470   0.250        1.2830          0.4620
# 1417   M   0.705     0.565   0.515        2.2100          1.1075
# 2051   F   0.455     0.355   1.130        0.5940          0.3320
#
#       Viscera_weight  Shell_weight  Rings
# 3996          0.0285        0.3505      6
# 1257          0.0860        0.1150      8
# 236           0.0005        0.0015      1
# 2169          0.0030        0.0050      4
# 1174          0.3080        0.2885      9
# ...              ...           ...    ...
# 1763          0.7600        0.5780     12
# 1428          0.4200        0.7975     14
# 2179          0.2475        0.4450     14
# 1417          0.4865        0.5120     10
# 2051          0.1160        0.1335      8
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 16
# Sort the data accoring to Diameter in descending order

# %%
df.sort_values('Diameter', ascending=False)
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1763   M   0.775     0.630   0.250        2.7795          1.3485
# 1207   F   0.755     0.625   0.210        2.5050          1.1965
# ...   ..     ...       ...     ...           ...             ...
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 236    I   0.075     0.055   0.010        0.0020          0.0010
#
#       Viscera_weight  Shell_weight  Rings
# 1428          0.4200        0.7975     14
# 1209          0.4985        0.5860     11
# 2334          0.5900        0.6200     23
# 1763          0.7600        0.5780     12
# 1207          0.5130        0.6785     11
# ...              ...           ...    ...
# 719           0.0040        0.0050      2
# 237           0.0030        0.0040      3
# 2114          0.0065        0.0035      4
# 238           0.0020        0.0030      3
# 236           0.0005        0.0015      1
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 17
# Sort the data first accoring to Length and then Height all ascending

# %%
df.sort_values(['Length', 'Height'])
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# ...   ..     ...       ...     ...           ...             ...
# 1763   M   0.775     0.630   0.250        2.7795          1.3485
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 237           0.0030        0.0040      3
# 2114          0.0065        0.0035      4
# 1986          0.0065        0.0080      4
# ...              ...           ...    ...
# 1763          0.7600        0.5780     12
# 3715          0.5745        0.6745     11
# 1209          0.4985        0.5860     11
# 2334          0.5900        0.6200     23
# 1428          0.4200        0.7975     14
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 18
# Sort the data according to Length, Diameter and Height in the same order and all in ascending order

# %%
df.sort_values(['Length', 'Diameter', 'Height'])
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# ...   ..     ...       ...     ...           ...             ...
# 1763   M   0.775     0.630   0.250        2.7795          1.3485
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# 1986          0.0065        0.0080      4
# ...              ...           ...    ...
# 1763          0.7600        0.5780     12
# 3715          0.5745        0.6745     11
# 1209          0.4985        0.5860     11
# 2334          0.5900        0.6200     23
# 1428          0.4200        0.7975     14
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 19
# Sort the data first accoring to Length (ascending) and then Height (descending)

# %%
df.sort_values(['Length', 'Height'], ascending=[True, False])
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# ...   ..     ...       ...     ...           ...             ...
# 2090   M   0.775     0.570   0.220        2.0320          0.7350
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# 1986          0.0065        0.0080      4
# ...              ...           ...    ...
# 2090          0.4755        0.6585     17
# 1209          0.4985        0.5860     11
# 3715          0.5745        0.6745     11
# 2334          0.5900        0.6200     23
# 1428          0.4200        0.7975     14
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 20
# Sort the data according to Length (ascending), Diameter (descending) and Height (ascending) in the same order

# %%
df.sort_values(['Length', 'Diameter', 'Height'], ascending=[True, False, True])
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# ...   ..     ...       ...     ...           ...             ...
# 2090   M   0.775     0.570   0.220        2.0320          0.7350
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 237           0.0030        0.0040      3
# 2114          0.0065        0.0035      4
# 1986          0.0065        0.0080      4
# ...              ...           ...    ...
# 2090          0.4755        0.6585     17
# 1209          0.4985        0.5860     11
# 3715          0.5745        0.6745     11
# 2334          0.5900        0.6200     23
# 1428          0.4200        0.7975     14
#
# [4177 rows x 9 columns]

# %% [markdown]
# # 21
# On average check who weights more males or females

# %%
df.groupby('Sex').mean()
# Out:
#        Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Sex
# F    0.579093  0.454732  0.158011      1.046532        0.446188
# I    0.427746  0.326494  0.107996      0.431363        0.191035
# M    0.561391  0.439287  0.151381      0.991459        0.432946
#
#      Viscera_weight  Shell_weight      Rings
# Sex
# F          0.230689      0.302010  11.129304
# I          0.092010      0.128182   7.890462
# M          0.215545      0.281969  10.705497

# %% [markdown]
# As apparent, Female Abalones weigh more, though by a small fraction.

# %% [markdown]
# # 22
# Check the maximum height when grouped by Sex

# %%
df.groupby('Sex').max().Height
# Out:
# Sex
# F    1.130
# I    0.220
# M    0.515
# Name: Height, dtype: float64

# %% [markdown]
# # 23
# Check the minimum Length in each gender when grouped by Sex

# %%
df.groupby('Sex').min().Length
# Out:
# Sex
# F    0.275
# I    0.075
# M    0.155
# Name: Length, dtype: float64

# %% [markdown]
# # 24
# From the dataframe, select only the Diameter column without using loc or iloc

# %%
df.Diameter
# Out:
# 0       0.365
# 1       0.265
# 2       0.420
# 3       0.365
# 4       0.255
#         ...
# 4172    0.450
# 4173    0.440
# 4174    0.475
# 4175    0.485
# 4176    0.555
# Name: Diameter, Length: 4177, dtype: float64

# %%
df['Diameter']
# Out:
# 0       0.365
# 1       0.265
# 2       0.420
# 3       0.365
# 4       0.255
#         ...
# 4172    0.450
# 4173    0.440
# 4174    0.475
# 4175    0.485
# 4176    0.555
# Name: Diameter, Length: 4177, dtype: float64

# %% [markdown]
# # 25
# From the dataframe select the Diameter and the Length columns without using loc or iloc

# %%
df[['Diameter', 'Length']]
# Out:
#       Diameter  Length
# 0        0.365   0.455
# 1        0.265   0.350
# 2        0.420   0.530
# 3        0.365   0.440
# 4        0.255   0.330
# ...        ...     ...
# 4172     0.450   0.565
# 4173     0.440   0.590
# 4174     0.475   0.600
# 4175     0.485   0.625
# 4176     0.555   0.710
#
# [4177 rows x 2 columns]

# %% [markdown]
# # 26
# Select the rows from index of 10 to 15 using iloc

# %%
df.iloc[10:16]
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 10   F   0.525     0.380   0.140        0.6065          0.1940
# 11   M   0.430     0.350   0.110        0.4060          0.1675
# 12   M   0.490     0.380   0.135        0.5415          0.2175
# 13   F   0.535     0.405   0.145        0.6845          0.2725
# 14   F   0.470     0.355   0.100        0.4755          0.1675
# 15   M   0.500     0.400   0.130        0.6645          0.2580
#
#     Viscera_weight  Shell_weight  Rings
# 10          0.1475         0.210     14
# 11          0.0810         0.135     10
# 12          0.0950         0.190     11
# 13          0.1710         0.205     10
# 14          0.0805         0.185     10
# 15          0.1330         0.240     12

# %% [markdown]
# # 27
# Select the first five rows using iloc

# %%
df.iloc[:5]
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 28
# Select the last 7 rows using iloc

# %%
df.iloc[-7:]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 4170   M   0.550     0.430   0.130        0.8395          0.3155
# 4171   M   0.560     0.430   0.155        0.8675          0.4000
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 4170          0.1955        0.2405     10
# 4171          0.1720        0.2290      8
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# # 29
# Select the row indexes 10 to 15 and column indexes 2 to 5 using iloc

# %%
df.iloc[10:16, 2: 6]
# Out:
#     Diameter  Height  Whole_weight  Shucked_weight
# 10     0.380   0.140        0.6065          0.1940
# 11     0.350   0.110        0.4060          0.1675
# 12     0.380   0.135        0.5415          0.2175
# 13     0.405   0.145        0.6845          0.2725
# 14     0.355   0.100        0.4755          0.1675
# 15     0.400   0.130        0.6645          0.2580

# %% [markdown]
# # 30
# Select the first five rows and the last five column indexes using iloc

# %%
df.iloc[:5, -5:]
# Out:
#    Whole_weight  Shucked_weight  Viscera_weight  Shell_weight  Rings
# 0        0.5140          0.2245          0.1010         0.150     15
# 1        0.2255          0.0995          0.0485         0.070      7
# 2        0.6770          0.2565          0.1415         0.210      9
# 3        0.5160          0.2155          0.1140         0.155     10
# 4        0.2050          0.0895          0.0395         0.055      7

# %% [markdown]
# # 31
# Select the rows 5 to 10 using loc

# %%
df.loc[5:10]
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 5    I   0.425     0.300   0.095        0.3515          0.1410
# 6    F   0.530     0.415   0.150        0.7775          0.2370
# 7    F   0.545     0.425   0.125        0.7680          0.2940
# 8    M   0.475     0.370   0.125        0.5095          0.2165
# 9    F   0.550     0.440   0.150        0.8945          0.3145
# 10   F   0.525     0.380   0.140        0.6065          0.1940
#
#     Viscera_weight  Shell_weight  Rings
# 5           0.0775         0.120      8
# 6           0.1415         0.330     20
# 7           0.1495         0.260     16
# 8           0.1125         0.165      9
# 9           0.1510         0.320     19
# 10          0.1475         0.210     14

# %% [markdown]
# # 32
# Select rows 100 to 105 and columns Height to Shell_weight using loc

# %%
df.loc[100:105, 'Height': 'Shell_weight']
# Out:
#      Height  Whole_weight  Shucked_weight  Viscera_weight  Shell_weight
# 100   0.095        0.2315          0.1050          0.0460         0.075
# 101   0.145        0.8430          0.3280          0.1915         0.255
# 102   0.160        0.8830          0.3160          0.1640         0.335
# 103   0.140        0.7240          0.3105          0.1675         0.205
# 104   0.160        1.1735          0.4975          0.2405         0.345
# 105   0.155        0.7270          0.2910          0.1835         0.235

# %% [markdown]
# # 33
# Select the first two rows and first two columns using loc

# %%
df.loc[:1, :'Length']
# Out:
#   Sex  Length
# 0   M   0.455
# 1   M   0.350

# %% [markdown]
# # 34
# Select only rows with indexes 100, 150, 130 and 110 using loc

# %%
df.loc[[100, 150, 130, 110]]
# Out:
#     Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 100   I   0.360     0.265   0.095        0.2315          0.1050
# 150   M   0.590     0.475   0.145        1.0530          0.4415
# 130   M   0.595     0.480   0.165        1.2620          0.4835
# 110   M   0.495     0.395   0.125        0.5415          0.2375
#
#      Viscera_weight  Shell_weight  Rings
# 100          0.0460         0.075      7
# 150          0.2620         0.325     15
# 130          0.2830         0.410     17
# 110          0.1345         0.155      9

# %% [markdown]
# # 35
# Select the columns Length, Rings and Height using loc

# %%
df.loc[:, ['Length', 'Rings', 'Height']]
# Out:
#       Length  Rings  Height
# 0      0.455     15   0.095
# 1      0.350      7   0.090
# 2      0.530      9   0.135
# 3      0.440     10   0.125
# 4      0.330      7   0.080
# ...      ...    ...     ...
# 4172   0.565     11   0.165
# 4173   0.590     10   0.135
# 4174   0.600      9   0.205
# 4175   0.625     10   0.150
# 4176   0.710     12   0.195
#
# [4177 rows x 3 columns]

# %% [markdown]
# # 36
# Select the rows 100, 150 and 99 and columns Length, Rings and Height

# %%
df.loc[[100, 150, 99], ['Length', 'Rings', 'Height']]
# Out:
#      Length  Rings  Height
# 100   0.360      7   0.095
# 150   0.590     15   0.145
# 99    0.475     10   0.125

# %% [markdown]
# # 37
# Draw a line plot of Whole_weight

# %%
df.Whole_weight.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 38
# Draw the line plot of Whole_weight and Rings (representing age) on same plot

# %%
df.Whole_weight.plot()
df.Rings.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Due to unordered dataset, it is really difficult to study the relationship between Whole_weight and Rings. Let's try to fix this.

# %% [markdown]
# # 39
# Sort the data accoring to Whole_weight and store the result in sorted_df

# %%
sorted_df = df.sort_values('Whole_weight')
sorted_df.head()
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# 1429          0.0025        0.0040      3

# %% [markdown]
# # 40
# As apparent the index of rows seems random now. Reset the indexes without adding any new columns.

# %%
sorted_df.reset_index(drop=True, inplace=True)
sorted_df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   I   0.075     0.055   0.010        0.0020          0.0010          0.0005
# 1   I   0.110     0.090   0.030        0.0080          0.0025          0.0020
# 2   I   0.130     0.095   0.035        0.0105          0.0050          0.0065
# 3   I   0.130     0.100   0.030        0.0130          0.0045          0.0030
# 4   I   0.140     0.105   0.035        0.0140          0.0055          0.0025
#
#    Shell_weight  Rings
# 0        0.0015      1
# 1        0.0030      3
# 2        0.0035      4
# 3        0.0040      3
# 4        0.0040      3

# %% [markdown]
# # 41
# Now draw the plot of Whole_weight again, this time using sorted_df

# %%
sorted_df.Whole_weight.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 42
# Now that the dataset is sorted, lets try plotting Whole_weight and Rings again but this time using sorted_df

# %%
sorted_df.Whole_weight.plot()
sorted_df.Rings.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 43
# The relation between Whole_weight and Rings is now more prominent. As Rings (age) increases, Whole_weight also increses.
#
# But since Whole_weight and Rings are present across different scales, lets try to bring them to same scale by multiplying Whole_weight by 10 and plotting afterwards
#
# | Column | Before Scale Factor Min | After Scaling Factor Min | Before Scale Factor Max | After Scale Factor Max |
# | --- | --- | --- | --- | --- |
# | Whole_weight | 0.002 | 0.02 | 2.82 | 28.2 |
# | Rings | 1 | 1 | 29 | 29 |

# %%
scaled_whole_weight = sorted_df.Whole_weight * 10
scaled_whole_weight.plot()
sorted_df.Rings.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Since we are plotting Whole_weight first, it overlaps Rings. Lets try to plot Rings first and Whole_weight afterwards.

# %%
sorted_df.Rings.plot()
scaled_whole_weight = sorted_df.Whole_weight * 10
scaled_whole_weight.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now the relationship between Rings and Whole_weight is clearly visible. As one increases, the other one also increases as expected.

# %% [markdown]
# # 44
# As we have seen above, there is a clear linear relationship between columns. Lets try to explore such relationships futher using coorelation. Calculate the correlation between all the columns.

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole_weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked_weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera_weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell_weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera_weight  Shell_weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole_weight          0.966375      0.955355  0.540390
# Shucked_weight        0.931961      0.882617  0.420884
# Viscera_weight        1.000000      0.907656  0.503819
# Shell_weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %% [markdown]
# # 45
# Select all the Abalones with the Length more than 0.75

# %%
df[df.Length > 0.75]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1052   M   0.765     0.600   0.220        2.3020          1.0070
# 1207   F   0.755     0.625   0.210        2.5050          1.1965
# 1208   M   0.755     0.580   0.205        2.0065          0.8295
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 1428   F   0.815     0.650   0.250        2.2550          0.8905
# 1762   M   0.770     0.620   0.195        2.5155          1.1155
# 1763   M   0.775     0.630   0.250        2.7795          1.3485
# 1985   M   0.760     0.605   0.215        2.1730          0.8010
# 2090   M   0.775     0.570   0.220        2.0320          0.7350
# 2334   F   0.800     0.630   0.195        2.5260          0.9330
# 2624   M   0.765     0.585   0.180        2.3980          1.1280
# 2625   M   0.770     0.600   0.215        2.1945          1.0515
# 3082   F   0.755     0.575   0.200        2.0730          1.0135
# 3715   M   0.780     0.600   0.210        2.5480          1.1945
# 3896   M   0.760     0.575   0.190        1.8290          0.7035
# 4148   M   0.770     0.605   0.175        2.0505          0.8005
#
#       Viscera_weight  Shell_weight  Rings
# 1052          0.5090        0.6205     12
# 1207          0.5130        0.6785     11
# 1208          0.4015        0.5950     10
# 1209          0.4985        0.5860     11
# 1428          0.4200        0.7975     14
# 1762          0.6415        0.6420     12
# 1763          0.7600        0.5780     12
# 1985          0.4915        0.6460     13
# 2090          0.4755        0.6585     17
# 2334          0.5900        0.6200     23
# 2624          0.5120        0.5335     12
# 2625          0.4820        0.5840     10
# 3082          0.4655        0.4800     11
# 3715          0.5745        0.6745     11
# 3896          0.3860        0.5600     14
# 4148          0.5260        0.3550     11

# %% [markdown]
# # 46
# Select all the Abalones with Shell_weight of 0.005 or less

# %%
df[df.Shell_weight <= 0.005]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 239    I   0.160     0.120   0.035        0.0210          0.0075
# 306    I   0.165     0.120   0.030        0.0215          0.0070
# 525    M   0.175     0.125   0.040        0.0240          0.0095
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# 694    I   0.165     0.110   0.020        0.0190          0.0065
# 696    I   0.155     0.105   0.050        0.0175          0.0050
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 720    I   0.160     0.110   0.025        0.0180          0.0065
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 2169   I   0.165     0.115   0.015        0.0145          0.0055
# 3837   I   0.170     0.105   0.035        0.0340          0.0120
# 3899   I   0.140     0.105   0.035        0.0145          0.0050
# 3902   I   0.160     0.120   0.020        0.0180          0.0075
#
#       Viscera_weight  Shell_weight  Rings
# 236           0.0005        0.0015      1
# 237           0.0030        0.0040      3
# 238           0.0020        0.0030      3
# 239           0.0045        0.0050      5
# 306           0.0050        0.0050      3
# 525           0.0060        0.0050      4
# 526           0.0030        0.0050      3
# 694           0.0025        0.0050      4
# 696           0.0035        0.0050      4
# 719           0.0040        0.0050      2
# 720           0.0055        0.0050      3
# 1429          0.0025        0.0040      3
# 2114          0.0065        0.0035      4
# 2169          0.0030        0.0050      4
# 3837          0.0085        0.0050      4
# 3899          0.0035        0.0050      4
# 3902          0.0045        0.0050      4

# %% [markdown]
# # 47
# Select all Abalones with Length more than 0.5 and Rings less than 7

# %%
df[(df.Length>0.5) & (df.Rings<7)]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 860    F   0.595     0.475   0.160        1.1405          0.5470
# 1039   F   0.660     0.475   0.180        1.3695          0.6410
# 1105   F   0.510     0.400   0.125        0.5450          0.2610
# 1584   F   0.515     0.375   0.110        0.6065          0.3005
# 1881   I   0.550     0.450   0.130        0.8040          0.3375
# 2581   F   0.530     0.420   0.170        0.8280          0.4100
# 2582   M   0.530     0.410   0.140        0.6810          0.3095
# 3982   I   0.580     0.435   0.150        0.8915          0.3630
# 3983   F   0.585     0.450   0.125        0.8740          0.3545
#
#       Viscera_weight  Shell_weight  Rings
# 860           0.2310        0.2710      6
# 1039          0.2940        0.3350      6
# 1105          0.1150        0.1385      6
# 1584          0.1310        0.1500      6
# 1881          0.1405        0.2300      6
# 2581          0.2080        0.1505      6
# 2582          0.1415        0.1835      6
# 3982          0.1925        0.2515      6
# 3983          0.2075        0.2250      6

# %% [markdown]
# # 48
# Select all Abalones with Diamter more than 0.3 and Height more than 0.4

# %%
df[(df.Diameter > 0.3) & (df.Height > 0.4)]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1417   M   0.705     0.565   0.515         2.210          1.1075
# 2051   F   0.455     0.355   1.130         0.594          0.3320
#
#       Viscera_weight  Shell_weight  Rings
# 1417          0.4865        0.5120     10
# 2051          0.1160        0.1335      8

# %% [markdown]
# # 49
# Select all Abalones with Rings of 29 or Shell_weight of more than 1

# %%
df[(df.Rings == 29) | (df.Shell_weight > 1)]
# Out:
#     Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 163   F   0.725     0.560   0.210        2.1410          0.6500
# 480   F   0.700     0.585   0.185        1.8075          0.7055
#
#      Viscera_weight  Shell_weight  Rings
# 163          0.3980         1.005     18
# 480          0.3215         0.475     29

# %% [markdown]
# # 50
# Create a deep copy of the dataframe to a variable called df_copy

# %%
df_copy = df.copy()

# %% [markdown]
# # 51
# 1 milimeter = 100 decimeter
#
# Convert all the values in **df_copy** Length, Diameter, Height to decimeter
#
# Note: If you accidentally do this change in df instead of df_copy, you will need to re-read the dataset using pd.read_csv

# %%
df_copy.Length = df_copy.Length * 100
df_copy.Diameter = df_copy.Diameter * 100
df_copy.Height = df_copy.Diameter * 100

# %%
df_copy.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M    45.5      36.5  3650.0        0.5140          0.2245          0.1010
# 1   M    35.0      26.5  2650.0        0.2255          0.0995          0.0485
# 2   F    53.0      42.0  4200.0        0.6770          0.2565          0.1415
# 3   M    44.0      36.5  3650.0        0.5160          0.2155          0.1140
# 4   I    33.0      25.5  2550.0        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # 52
# Change the column names in df_copy to reflect the above change
#
# | Old Column Name | New Column Name |
# | --- | --- |
# | Length | Length_dm |
# | Diameter | Diameter_dm |
# | Height | Height_dm |

# %%
rename_vals = {
    'Length': 'Length_dm',
    'Diameter': 'Diameter_dm',
    'Height': 'Height_dm'
}

df_copy.rename(columns=rename_vals, inplace=True)

# %% [markdown]
# # 53
# The values in **df_copy** in columns Whole_weight, Shucked_weight, Viscera_weight and Shell_weight are given in grams, convert them into milligrams
#
# Note: 1 gram = 1000 milligrams. Also, If you accidentally do this change in df instead of df_copy, you will need to re-read the dataset using pd.read_csv.

# %%
df_copy.Whole_weight = df_copy.Whole_weight * 1000
df_copy.Shucked_weight = df_copy.Shucked_weight * 1000
df_copy.Viscera_weight = df_copy.Viscera_weight * 1000
df_copy.Shell_weight = df_copy.Shell_weight * 1000

# %%
df_copy.head()
# Out:
#   Sex  Length_dm  Diameter_dm  Height_dm  Whole_weight  Shucked_weight  \
# 0   M       45.5         36.5     3650.0         514.0           224.5
# 1   M       35.0         26.5     2650.0         225.5            99.5
# 2   F       53.0         42.0     4200.0         677.0           256.5
# 3   M       44.0         36.5     3650.0         516.0           215.5
# 4   I       33.0         25.5     2550.0         205.0            89.5
#
#    Viscera_weight  Shell_weight  Rings
# 0           101.0         150.0     15
# 1            48.5          70.0      7
# 2           141.5         210.0      9
# 3           114.0         155.0     10
# 4            39.5          55.0      7

# %% [markdown]
# # 54
# Rename the **df_copy** columns to reflect this change
#
# | Old Column Name | New Column Name |
# | --- | --- |
# | Whole_weight | Whole_weight_mg |
# | Shucked_weight | Shucked_weight_mg |
# | Viscera_weight | Viscera_weight_mg |
# | Shell_weight | Shell_weight_mg |

# %%
rename_vals = {
    'Whole_weight': 'Whole_weight_mg',
    'Shucked_weight': 'Shucked_weight_mg',
    'Viscera_weight': 'Viscera_weight_mg',
    'Shell_weight': 'Shell_weight_mg'
}

df_copy.rename(columns=rename_vals, inplace=True)

# %%
df_copy.head()
# Out:
#   Sex  Length_dm  Diameter_dm  Height_dm  Whole_weight_mg  Shucked_weight_mg  \
# 0   M       45.5         36.5     3650.0            514.0              224.5
# 1   M       35.0         26.5     2650.0            225.5               99.5
# 2   F       53.0         42.0     4200.0            677.0              256.5
# 3   M       44.0         36.5     3650.0            516.0              215.5
# 4   I       33.0         25.5     2550.0            205.0               89.5
#
#    Viscera_weight_mg  Shell_weight_mg  Rings
# 0              101.0            150.0     15
# 1               48.5             70.0      7
# 2              141.5            210.0      9
# 3              114.0            155.0     10
# 4               39.5             55.0      7

# %% [markdown]
# # 55
# Delete the columns Sex and Rings from **df_copy**

# %%
df_copy.drop(['Sex', 'Rings'], axis=1, inplace=True)
df_copy.head()
# Out:
#    Length_dm  Diameter_dm  Height_dm  Whole_weight_mg  Shucked_weight_mg  \
# 0       45.5         36.5     3650.0            514.0              224.5
# 1       35.0         26.5     2650.0            225.5               99.5
# 2       53.0         42.0     4200.0            677.0              256.5
# 3       44.0         36.5     3650.0            516.0              215.5
# 4       33.0         25.5     2550.0            205.0               89.5
#
#    Viscera_weight_mg  Shell_weight_mg
# 0              101.0            150.0
# 1               48.5             70.0
# 2              141.5            210.0
# 3              114.0            155.0
# 4               39.5             55.0

# %% [markdown]
# # 56
# Add another column to **df_copy** named Length_mm containing all Length_dm values in mm
#
# Note: 100 dm = 1 mm

# %%
df_copy['Length_mm'] = df_copy.Length_dm / 100
df_copy.head()
# Out:
#    Length_dm  Diameter_dm  Height_dm  Whole_weight_mg  Shucked_weight_mg  \
# 0       45.5         36.5     3650.0            514.0              224.5
# 1       35.0         26.5     2650.0            225.5               99.5
# 2       53.0         42.0     4200.0            677.0              256.5
# 3       44.0         36.5     3650.0            516.0              215.5
# 4       33.0         25.5     2550.0            205.0               89.5
#
#    Viscera_weight_mg  Shell_weight_mg  Length_mm
# 0              101.0            150.0      0.455
# 1               48.5             70.0      0.350
# 2              141.5            210.0      0.530
# 3              114.0            155.0      0.440
# 4               39.5             55.0      0.330
